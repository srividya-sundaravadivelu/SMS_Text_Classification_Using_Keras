# %% [markdown]
# <a href="https://colab.research.google.com/github/srividya-sundaravadivelu/SMS_Text_Classification_Using_Keras/blob/main/sms_text_classification_keras_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
from tensorflow import keras
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt

# %%
# get data files
# !wget https://cdn.freecodecamp.org/project-data/sms/train-data.tsv
# !wget https://cdn.freecodecamp.org/project-data/sms/valid-data.tsv

train_file_path = "train-data.tsv"
test_file_path = "valid-data.tsv"
# Out:
# --2022-03-14 17:51:55--  https://cdn.freecodecamp.org/project-data/sms/train-data.tsv
# Resolving cdn.freecodecamp.org (cdn.freecodecamp.org)... 104.26.2.33, 104.26.3.33, 172.67.70.149, ...
# Connecting to cdn.freecodecamp.org (cdn.freecodecamp.org)|104.26.2.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 358233 (350K) [text/tab-separated-values]
# Saving to: ‘train-data.tsv.1’
#
# train-data.tsv.1    100%[===================>] 349.84K  --.-KB/s    in 0.01s
#
# 2022-03-14 17:51:55 (25.6 MB/s) - ‘train-data.tsv.1’ saved [358233/358233]
#
# --2022-03-14 17:51:55--  https://cdn.freecodecamp.org/project-data/sms/valid-data.tsv
# Resolving cdn.freecodecamp.org (cdn.freecodecamp.org)... 104.26.2.33, 104.26.3.33, 172.67.70.149, ...
# Connecting to cdn.freecodecamp.org (cdn.freecodecamp.org)|104.26.2.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 118774 (116K) [text/tab-separated-values]
# Saving to: ‘valid-data.tsv.1’
#
# valid-data.tsv.1    100%[===================>] 115.99K  --.-KB/s    in 0.005s
#
# 2022-03-14 17:51:55 (22.1 MB/s) - ‘valid-data.tsv.1’ saved [118774/118774]

# %%
df_train = pd.read_csv(train_file_path,sep="\t",header=None)

# %%
df_train = df_train.rename(columns={0: 'HamOrSpam',1: 'Text'})
df_train
# Out:
#      HamOrSpam                                               Text
# 0          ham  ahhhh...just woken up!had a bad dream about u ...
# 1          ham                           you can never do nothing
# 2          ham  now u sound like manky scouse boy steve,like! ...
# 3          ham  mum say we wan to go then go... then she can s...
# 4          ham  never y lei... i v lazy... got wat? dat day ü ...
# ...        ...                                                ...
# 4174       ham  just woke up. yeesh its late. but i didn't fal...
# 4175       ham  what do u reckon as need 2 arrange transport i...
# 4176      spam  free entry into our £250 weekly competition ju...
# 4177      spam  -pls stop bootydelious (32/f) is inviting you ...
# 4178       ham  tell my  bad character which u dnt lik in me. ...
#
# [4179 rows x 2 columns]

# %%
df_test = pd.read_csv(test_file_path,sep="\t",header=None)
df_test
# Out:
#          0                                                  1
# 0      ham  i am in hospital da. . i will return home in e...
# 1      ham         not much, just some textin'. how bout you?
# 2      ham  i probably won't eat at all today. i think i'm...
# 3      ham  don‘t give a flying monkeys wot they think and...
# 4      ham                                who are you seeing?
# ...    ...                                                ...
# 1387   ham  true dear..i sat to pray evening and felt so.s...
# 1388   ham               what will we do in the shower, baby?
# 1389   ham  where are you ? what are you doing ? are yuou ...
# 1390  spam  ur cash-balance is currently 500 pounds - to m...
# 1391  spam  not heard from u4 a while. call 4 rude chat pr...
#
# [1392 rows x 2 columns]

# %%
df_test = df_test.rename(columns={0: 'HamOrSpam',1: 'Text'})
df_test
# Out:
#      HamOrSpam                                               Text
# 0          ham  i am in hospital da. . i will return home in e...
# 1          ham         not much, just some textin'. how bout you?
# 2          ham  i probably won't eat at all today. i think i'm...
# 3          ham  don‘t give a flying monkeys wot they think and...
# 4          ham                                who are you seeing?
# ...        ...                                                ...
# 1387       ham  true dear..i sat to pray evening and felt so.s...
# 1388       ham               what will we do in the shower, baby?
# 1389       ham  where are you ? what are you doing ? are yuou ...
# 1390      spam  ur cash-balance is currently 500 pounds - to m...
# 1391      spam  not heard from u4 a while. call 4 rude chat pr...
#
# [1392 rows x 2 columns]

# %%
# Convert Categorical to numeric.
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
df_train["HamOrSpam"] = labelEncoder.fit_transform(df_train["HamOrSpam"])
df_test["HamOrSpam"] = labelEncoder.fit_transform(df_test["HamOrSpam"])

# %%
df_train.head()
# Out:
#    HamOrSpam                                               Text
# 0          0  ahhhh...just woken up!had a bad dream about u ...
# 1          0                           you can never do nothing
# 2          0  now u sound like manky scouse boy steve,like! ...
# 3          0  mum say we wan to go then go... then she can s...
# 4          0  never y lei... i v lazy... got wat? dat day ü ...

# %%
df_test.head()
# Out:
#    HamOrSpam                                               Text
# 0          0  i am in hospital da. . i will return home in e...
# 1          0         not much, just some textin'. how bout you?
# 2          0  i probably won't eat at all today. i think i'm...
# 3          0  don‘t give a flying monkeys wot they think and...
# 4          0                                who are you seeing?

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4179 entries, 0 to 4178
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   HamOrSpam  4179 non-null   int64
#  1   Text       4179 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 65.4+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1392 entries, 0 to 1391
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   HamOrSpam  1392 non-null   int64
#  1   Text       1392 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 21.9+ KB

# %%
df_train["HamOrSpam"].value_counts(normalize=True)
# Out:
# 0    0.865997
# 1    0.134003
# Name: HamOrSpam, dtype: float64

# %%
X_train = df_train["Text"]
X_test = df_test["Text"]
y_train = df_train["HamOrSpam"]
y_test = df_test["HamOrSpam"]

# %%
print(X_train.head())
print(X_test.head())
print(y_train.head())
print(y_test.head())
# Out:
# 0    ahhhh...just woken up!had a bad dream about u ...
# 1                             you can never do nothing
# 2    now u sound like manky scouse boy steve,like! ...
# 3    mum say we wan to go then go... then she can s...
# 4    never y lei... i v lazy... got wat? dat day ü ...
# Name: Text, dtype: object
# 0    i am in hospital da. . i will return home in e...
# 1           not much, just some textin'. how bout you?
# 2    i probably won't eat at all today. i think i'm...
# 3    don‘t give a flying monkeys wot they think and...
# 4                                  who are you seeing?
# Name: Text, dtype: object
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: HamOrSpam, dtype: int64
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: HamOrSpam, dtype: int64

# %%
X_train = np.array(X_train)

# %%
X_test = np.array(X_test)

# %%
vectorize_layer = keras.layers.TextVectorization()
vectorize_layer.adapt(X_train)

# %%
vectorize_layer.get_vocabulary()
# Out:
# ['',
#  '[UNK]',
#  'to',
#  'i',
#  'you',
#  'a',
#  'the',
#  'u',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'of',
#  'it',
#  'call',
#  'have',
#  'on',
#  'that',
#  'are',
#  'now',
#  'im',
#  '2',
#  'not',
#  'but',
#  'so',
#  'at',
#  'or',
#  'do',
#  'can',
#  'with',
#  'be',
#  'will',
#  'if',
#  'get',
#  'ur',
#  'just',
#  'we',
#  'this',
#  'no',
#  'its',
#  'up',
#  'go',
#  '4',
#  'ok',
#  'dont',
#  'ltgt',
#  'free',
#  'when',
#  'out',
#  'how',
#  'all',
#  'what',
#  'from',
#  'know',
#  'like',
#  'got',
#  'then',
#  'come',
#  'good',
#  'ill',
#  'time',
#  'am',
#  'was',
#  'only',
#  'day',
#  'he',
#  'love',
#  'send',
#  'there',
#  'as',
#  'want',
#  'text',
#  'going',
#  'by',
#  'ü',
#  'one',
#  'about',
#  'need',
#  'txt',
#  'lor',
#  'still',
#  'our',
#  'see',
#  'n',
#  'r',
#  'home',
#  'stop',
#  'sorry',
#  'reply',
#  'back',
#  'today',
#  'tell',
#  'she',
#  'new',
#  'been',
#  'mobile',
#  'later',
#  'take',
#  'hi',
#  'da',
#  'her',
#  'they',
#  'well',
#  'think',
#  'night',
#  'has',
#  'any',
#  'please',
#  'much',
#  'cant',
#  'week',
#  'dear',
#  'an',
#  'happy',
#  'some',
#  'pls',
#  'hey',
#  'did',
#  'phone',
#  'oh',
#  'who',
#  'too',
#  'here',
#  'make',
#  'great',
#  'where',
#  'way',
#  'him',
#  'work',
#  'tomorrow',
#  'd',
#  'more',
#  'hope',
#  'had',
#  'say',
#  'claim',
#  'wat',
#  'thats',
#  'number',
#  'give',
#  'should',
#  'really',
#  'ask',
#  'already',
#  'yes',
#  'were',
#  'amp',
#  'doing',
#  'after',
#  'yeah',
#  'right',
#  'e',
#  'said',
#  'message',
#  'cos',
#  'c',
#  '1',
#  'msg',
#  'miss',
#  'why',
#  'prize',
#  'ive',
#  'anything',
#  'life',
#  'last',
#  'very',
#  'sure',
#  'morning',
#  'cash',
#  'thanks',
#  'pick',
#  'nokia',
#  'gud',
#  'every',
#  'didnt',
#  'care',
#  'again',
#  'would',
#  'meet',
#  'find',
#  'babe',
#  'b',
#  'win',
#  'keep',
#  'them',
#  'off',
#  'k',
#  'also',
#  'let',
#  'gonna',
#  'feel',
#  'his',
#  'tonight',
#  'before',
#  'us',
#  'soon',
#  'someone',
#  'nice',
#  'next',
#  'first',
#  'even',
#  'around',
#  '3',
#  'which',
#  'sent',
#  'lol',
#  'won',
#  'wait',
#  'something',
#  'sleep',
#  'place',
#  'contact',
#  'ya',
#  'thk',
#  'service',
#  'always',
#  'wish',
#  'things',
#  'thing',
#  'per',
#  'over',
#  'name',
#  'late',
#  'friends',
#  'year',
#  'wont',
#  'waiting',
#  'urgent',
#  'money',
#  'leave',
#  'could',
#  'buy',
#  'told',
#  'same',
#  'people',
#  'help',
#  'customer',
#  'haha',
#  'friend',
#  'dun',
#  'may',
#  'many',
#  'chat',
#  '16',
#  'other',
#  'meeting',
#  'down',
#  'went',
#  'v',
#  'mins',
#  'class',
#  'best',
#  'youre',
#  'yet',
#  'wan',
#  'getting',
#  'done',
#  'coming',
#  'yup',
#  'tone',
#  'thought',
#  'never',
#  'lunch',
#  'holiday',
#  'hello',
#  'special',
#  'x',
#  'talk',
#  'hows',
#  'havent',
#  'finish',
#  'car',
#  'bit',
#  'better',
#  'being',
#  'try',
#  'stuff',
#  'man',
#  'lar',
#  'heart',
#  'guaranteed',
#  'cool',
#  'birthday',
#  '5',
#  '18',
#  'than',
#  'min',
#  'long',
#  'guys',
#  'fine',
#  'another',
#  'use',
#  'trying',
#  'start',
#  'mind',
#  'lot',
#  'live',
#  'liao',
#  'house',
#  'guess',
#  'few',
#  'end',
#  'dat',
#  'chance',
#  'yo',
#  'y',
#  'sms',
#  'smile',
#  'play',
#  'latest',
#  'into',
#  'box',
#  'because',
#  'account',
#  'watch',
#  'sweet',
#  'room',
#  'receive',
#  'person',
#  'nothing',
#  'line',
#  'having',
#  'half',
#  'enjoy',
#  'days',
#  'check',
#  'camera',
#  'big',
#  '1st',
#  'video',
#  'thanx',
#  'quite',
#  'problem',
#  'pa',
#  'offer',
#  'might',
#  'jus',
#  'id',
#  'hear',
#  'face',
#  'ever',
#  'eat',
#  'early',
#  'draw',
#  'aight',
#  'xxx',
#  'watching',
#  'remember',
#  'real',
#  'ready',
#  'probably',
#  'princess',
#  'po',
#  'pay',
#  'den',
#  'boy',
#  'awarded',
#  'apply',
#  '£1000',
#  'without',
#  'two',
#  'tmr',
#  'once',
#  'month',
#  'little',
#  'leh',
#  'job',
#  'girl',
#  'dinner',
#  'actually',
#  'world',
#  'word',
#  'whats',
#  'wanna',
#  'tv',
#  'tcs',
#  'speak',
#  'sir',
#  'part',
#  'minutes',
#  'made',
#  'look',
#  'landline',
#  'hour',
#  'dunno',
#  'does',
#  'ah',
#  '6',
#  'weekly',
#  'weekend',
#  'those',
#  'shows',
#  'shes',
#  'sat',
#  'must',
#  'missing',
#  'luv',
#  'easy',
#  'came',
#  'bus',
#  'bed',
#  'bad',
#  '2nd',
#  'yours',
#  'working',
#  'wanted',
#  'til',
#  'though',
#  'theres',
#  'since',
#  'shopping',
#  'shit',
#  'selected',
#  'school',
#  's',
#  'reach',
#  'put',
#  'okay',
#  'network',
#  'most',
#  'left',
#  'kiss',
#  'join',
#  'hes',
#  'hav',
#  'forgot',
#  'enough',
#  'dis',
#  'cost',
#  'code',
#  'called',
#  '7',
#  '150ppm',
#  '£2000',
#  'xmas',
#  'while',
#  'until',
#  'stay',
#  'shall',
#  'sexy',
#  'says',
#  'plan',
#  'pain',
#  'orange',
#  'making',
#  'guy',
#  'everything',
#  'entry',
#  'de',
#  'collection',
#  'collect',
#  'bt',
#  'baby',
#  'alright',
#  'town',
#  'tc',
#  'ringtone',
#  'rate',
#  'missed',
#  'looking',
#  'important',
#  'dad',
#  'away',
#  'ard',
#  'abt',
#  'able',
#  '9',
#  '£150',
#  'wid',
#  'trip',
#  'together',
#  'times',
#  'show',
#  'saw',
#  'oso',
#  'means',
#  'makes',
#  'haf',
#  'fun',
#  'fuck',
#  'bored',
#  'attempt',
#  '500',
#  'years',
#  'wot',
#  'wk',
#  'true',
#  'tones',
#  'run',
#  'price',
#  'points',
#  'maybe',
#  'juz',
#  'hurt',
#  'god',
#  'gift',
#  'game',
#  'g',
#  'evening',
#  'driving',
#  'doesnt',
#  'colour',
#  'book',
#  'between',
#  'asked',
#  'anyway',
#  'answer',
#  '150p',
#  '£100',
#  'yesterday',
#  'wif',
#  'wen',
#  'wake',
#  'update',
#  'tried',
#  'top',
#  'todays',
#  'thank',
#  'started',
#  'question',
#  'plz',
#  'order',
#  'old',
#  'nite',
#  'mean',
#  'm',
#  'hot',
#  'full',
#  'friendship',
#  'finished',
#  'either',
#  'dude',
#  'comes',
#  'club',
#  'brother',
#  'bring',
#  'aft',
#  '£5000',
#  '£500',
#  'worry',
#  'valid',
#  'till',
#  'thinking',
#  'texts',
#  'test',
#  'sch',
#  'sae',
#  'open',
#  'online',
#  'music',
#  'mob',
#  'mail',
#  'lose',
#  'lets',
#  'hours',
#  'goes',
#  'food',
#  'family',
#  'eve',
#  'else',
#  'dreams',
#  'double',
#  'change',
#  'calls',
#  'believe',
#  'award',
#  'await',
#  'address',
#  '8007',
#  'worth',
#  'weeks',
#  'wants',
#  'voucher',
#  'treat',
#  'tot',
#  'sun',
#  'statement',
#  'smoke',
#  'smiling',
#  'shop',
#  're',
#  'private',
#  'plus',
#  'okie',
#  'noe',
#  'movie',
#  'lucky',
#  'lei',
#  'head',
#  'hair',
#  'feeling',
#  'expires',
#  'email',
#  'drop',
#  'details',
#  'delivery',
#  'coz',
#  'congrats',
#  'choose',
#  'cause',
#  'calling',
#  'bonus',
#  'beautiful',
#  'afternoon',
#  '750',
#  'words',
#  'winner',
#  'wife',
#  'whatever',
#  'unsubscribe',
#  'unredeemed',
#  'touch',
#  'taking',
#  't',
#  'simple',
#  'set',
#  'services',
#  'second',
#  'saying',
#  'saturday',
#  'pounds',
#  'poly',
#  'pics',
#  'office',
#  'needs',
#  'mates',
#  'ltdecimalgt',
#  'loving',
#  'lots',
#  'lesson',
#  'leaving',
#  'kind',
#  'identifier',
#  'huh',
#  'happened',
#  'games',
#  'forget',
#  'date',
#  'charge',
#  'card',
#  'busy',
#  'both',
#  'awesome',
#  'auction',
#  'anytime',
#  'anyone',
#  'angry',
#  '£250',
#  'walk',
#  'vouchers',
#  'visit',
#  'unlimited',
#  'type',
#  'took',
#  'these',
#  'talking',
#  'story',
#  'sounds',
#  'smth',
#  'sister',
#  'search',
#  'rite',
#  'ring',
#  'party',
#  'parents',
#  'operator',
#  'mrng',
#  'minute',
#  'messages',
#  'listen',
#  'light',
#  'isnt',
#  'happen',
#  'ha',
#  'gr8',
#  'goin',
#  'gd',
#  'fri',
#  'fast',
#  'dating',
#  'close',
#  'camcorder',
#  'bday',
#  '86688',
#  '8',
#  '100',
#  '08000930705',
#  'yourself',
#  'their',
#  'read',
#  'pub',
#  'prob',
#  'oredi',
#  'o',
#  'nt',
#  'ni8',
#  'neva',
#  'mobileupd8',
#  'log',
#  'hit',
#  'goodmorning',
#  'gone',
#  'girls',
#  'frnd',
#  'fone',
#  'finally',
#  'enter',
#  'download',
#  'dnt',
#  'die',
#  'content',
#  'company',
#  'college',
#  'carlos',
#  'blue',
#  'available',
#  'alone',
#  '12hrs',
#  '08000839402',
#  '0800',
#  'youve',
#  'wrong',
#  'wonderful',
#  'wit',
#  'wil',
#  'w',
#  'tscs',
#  'tomo',
#  'tho',
#  'thinks',
#  'takes',
#  'song',
#  'snow',
#  'semester',
#  'secret',
#  'sad',
#  'project',
#  'pretty',
#  'post',
#  'pobox',
#  'offers',
#  'numbers',
#  'nope',
#  'noon',
#  'news',
#  'mu',
#  'motorola',
#  'ltd',
#  'loved',
#  'land',
#  'knw',
#  'jay',
#  'ipod',
#  'invited',
#  'hand',
#  'grins',
#  'gotta',
#  'gas',
#  'fucking',
#  'frnds',
#  'friday',
#  'fr',
#  'found',
#  'final',
#  'everyone',
#  'drink',
#  'cs',
#  'bank',
#  'b4',
#  'area',
#  'ans',
#  'almost',
#  '2003',
#  'youll',
#  'yar',
#  'write',
#  'wow',
#  'wats',
#  'used',
#  'tired',
#  'th',
#  'ten',
#  'sound',
#  'somebody',
#  'small',
#  'slowly',
#  'sis',
#  'side',
#  'seeing',
#  'sea',
#  'reading',
#  'point',
#  'pm',
#  'player',
#  'park',
#  'opt',
#  'nyt',
#  'national',
#  'muz',
#  'mum',
#  'msgs',
#  'mobiles',
#  'mine',
#  'meant',
#  'mayb',
#  'march',
#  'luck',
#  'lovely',
#  'information',
#  'hmv',
#  'hell',
#  'hard',
#  'happiness',
#  'gym',
#  'freemsg',
#  'fancy',
#  'extra',
#  'entered',
#  'energy',
#  'earlier',
#  'each',
#  'dream',
#  'decided',
#  'darlin',
#  'credit',
#  'crazy',
#  'course',
#  'congratulations',
#  'christmas',
#  'chikku',
#  'checking',
#  'case',
#  'bslvyl',
#  'bout',
#  'ass',
#  'askd',
#  '800',
#  '…',
#  'yr',
#  'xx',
#  'wonder',
#  'within',
#  'wine',
#  'wana',
#  'uk',
#  'txting',
#  'through',
#  'surprise',
#  'supposed',
#  'stupid',
#  'studying',
#  'specially',
#  'seriously',
#  'savamob',
#  'rental',
#  'remove',
#  'reason',
#  'reached',
#  'rates',
#  'pic',
#  'pete',
#  'pass',
#  'paper',
#  'optout',
#  'near',
#  'mode',
#  'mm',
#  'met',
#  'match',
#  'least',
#  'laptop',
#  'knew',
#  'info',
#  'india',
#  'hungry',
#  'hold',
#  'hee',
#  'frm',
#  'flag',
#  'father',
#  'far',
#  'ex',
#  'etc',
#  'england',
#  'ends',
#  'empty',
#  'em',
#  'eh',
#  'drugs',
#  'drive',
#  'don',
#  'direct',
#  'difficult',
#  'different',
#  'del',
#  'deep',
#  'cut',
#  'credits',
#  'complimentary',
#  'chennai',
#  'charity',
#  'charged',
#  'break',
#  'booked',
#  'asking',
#  'age',
#  'abiola',
#  '150',
#  '12',
#  '10',
#  'worries',
#  'worried',
#  'wkly',
#  'wishing',
#  'wishes',
#  'whole',
#  'welcome',
#  'weed',
#  'wednesday',
#  'wed',
#  'voice',
#  'via',
#  'valentine',
#  'using',
#  'usf',
#  'urself',
#  'uncle',
#  'thinkin',
#  'telling',
#  'tel',
#  'tampa',
#  'swing',
#  'support',
#  'summer',
#  'store',
#  'std',
#  'spend',
#  'sleeping',
#  'sim',
#  'sign',
#  'shower',
#  'rply',
#  'rock',
#  'reward',
#  'registered',
#  'questions',
#  'poor',
#  'picking',
#  'phones',
#  'outside',
#  'oops',
#  'ones',
#  'ntt',
#  'no1',
#  'mr',
#  'move',
#  'mood',
#  'mom',
#  'merry',
#  'mate',
#  'mah',
#  'lover',
#  'lovable',
#  'link',
#  'lazy',
#  'laugh',
#  'kate',
#  'john',
#  'ice',
#  'hoping',
#  'ho',
#  'goto',
#  'gods',
#  'giving',
#  'gave',
#  'gal',
#  'forever',
#  'film',
#  'figure',
#  'felt',
#  'feels',
#  'fantastic',
#  'especially',
#  'eg',
#  'doin',
#  'disturb',
#  'discount',
#  'deal',
#  'darren',
#  'currently',
#  'couple',
#  'correct',
#  'convey',
#  'confirm',
#  'computer',
#  'completely',
#  'comp',
#  ...]

# %%
vocab_size = len(vectorize_layer.get_vocabulary())

# %%
model = tf.keras.Sequential([
    vectorize_layer,
    tf.keras.layers.Embedding(
        input_dim=vocab_size,
        output_dim=32,
        mask_zero=True),
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer="adam",
             loss = "binary_crossentropy",
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  text_vectorization_1 (TextV  (None, None)             0
#  ectorization)
#
#  embedding_1 (Embedding)     (None, None, 32)          261792
#
#  lstm_1 (LSTM)               (None, 32)                8320
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 271,201
# Trainable params: 271,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# early stopping callback
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                  mode="min", 
                                  patience=5,
                                  restore_best_weights=True)

# %%
mdl_history = model.fit(X_train,
         y_train,
         epochs = 15,
         validation_data = (X_test,y_test),
         callbacks = [callback])
# Out:
# Epoch 1/15
# 131/131 [==============================] - 15s 52ms/step - loss: 0.2978 - accuracy: 0.9174 - val_loss: 0.1032 - val_accuracy: 0.9591
# Epoch 2/15
# 131/131 [==============================] - 5s 41ms/step - loss: 0.0394 - accuracy: 0.9904 - val_loss: 0.0468 - val_accuracy: 0.9842
# Epoch 3/15
# 131/131 [==============================] - 5s 40ms/step - loss: 0.0140 - accuracy: 0.9969 - val_loss: 0.0516 - val_accuracy: 0.9820
# Epoch 4/15
# 131/131 [==============================] - 5s 39ms/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 0.0490 - val_accuracy: 0.9849
# Epoch 5/15
# 131/131 [==============================] - 5s 40ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.0552 - val_accuracy: 0.9842
# Epoch 6/15
# 131/131 [==============================] - 5s 39ms/step - loss: 8.6420e-04 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9842
# Epoch 7/15
# 131/131 [==============================] - 5s 40ms/step - loss: 6.3638e-04 - accuracy: 1.0000 - val_loss: 0.0648 - val_accuracy: 0.9842

# %%
pred_text = "sale today! to stop texts call 98912460324"

# %%
np.array([pred_text])
# Out:
# array(['sale today! to stop texts call 98912460324'], dtype='<U42')

# %%
result = model.predict(np.array([pred_text]))

# %%
result[0][0]
# Out:
# 0.89347184

# %%
# function to predict messages based on model
# (should return list containing prediction and label, ex. [0.008318834938108921, 'ham'])
def predict_message(pred_text):
  result = model.predict(np.array([pred_text]))
  if (result[0][0] >= 0.5):
    hamOrSpam = 'spam'
  else:
    hamOrSpam = 'ham'
  prediction = [result[0][0],hamOrSpam]
  return (prediction)

pred_text = "how are you doing today?"

prediction = predict_message(pred_text)
print(prediction)
# Out:
# [0.0008044541, 'ham']

# %%
# Run this cell to test your function and model. Do not modify contents.
def test_predictions():
  test_messages = ["how are you doing today",
                   "sale today! to stop texts call 98912460324",
                   "i dont want to go. can we try it a different day? available sat",
                   "our new mobile video service is live. just install on your phone to start watching.",
                   "you have won £1000 cash! call to claim your prize.",
                   "i'll bring it tomorrow. don't forget the milk.",
                   "wow, is your arm alright. that happened to me one time too"
                  ]

  test_answers = ["ham", "spam", "ham", "spam", "spam", "ham", "ham"]
  passed = True

  for msg, ans in zip(test_messages, test_answers):
    prediction = predict_message(msg)
    if prediction[1] != ans:  
      passed = False

  if passed:
    print("You passed the challenge. Great job!")
  else:
    print("You haven't passed yet. Keep trying.")

test_predictions()
# Out:
# You passed the challenge. Great job!
